# %%
#Необходимые библиотеки
import csv
import random
from datetime import datetime, timedelta
from tkinter import *
from tkinter import ttk
from matplotlib.figure import Figure 
from matplotlib.backends.backend_tkagg import (FigureCanvasTkAgg, NavigationToolbar2Tk) 
import matplotlib.pyplot as plt

# %%
def generate_date():
    start_date = datetime(2020, 9, 21)
    end_date = datetime(2022, 7, 15)
    random_date = start_date + timedelta(days=random.randint(0, (end_date - start_date).days))
    return random_date.strftime('%Y-%m-%d')

prod = [
    ('Молоко', 'Молочная продукция', random.randint(1, 200), random.randint(8500, 14000)),
    ('Кефир', 'Молочная продукция', random.randint(1, 65), random.randint(40000, 82000)),
    ('Йогурт', 'Молочная продукция', random.randint(1, 100), random.randint(17000, 75000)),
    ('Милка', 'Шоколад', random.randint(1, 2000), random.randint(1200, 2100)),
    ('Сникерс', 'Шоколад', random.randint(1, 1500), random.randint(2500, 4200)),
    ('Твикс', 'Шоколад', random.randint(1, 750), random.randint(5400, 8700)),
    ('Свинина', 'Мясо', random.randint(1, 1000), random.randint(4500, 19000)),
    ('Курица', 'Мясо', random.randint(1, 850), random.randint(200, 1500)),
    ('Говядина', 'Мясо', random.randint(1, 800), random.randint(600, 2000)),
    ('Лаваш', 'Хлеб', random.randint(1, 1700), random.randint(300, 1200)),
    ('Булочка с маком', 'Хлеб', random.randint(1, 1900), random.randint(500, 1800)),
    ('Пирожок с мясом', 'Хлеб', random.randint(1, 1000), random.randint(650, 1250)),
    ('Святой источник', 'Напитки', random.randint(1, 500), random.randint(3500, 8000)),
    ('Байкал', 'Напитки', random.randint(1, 600), random.randint(1800, 3000)),
    ('Витель', 'Напитки', random.randint(1, 250), random.randint(6000, 9500))
]

with open('Shop.csv', 'w',  newline='') as file:
    writer = csv.writer(file, delimiter='|')

    # Записываем заголовок
    writer.writerow(['Номер заказа', 'Дата заказа', 'Название товара', 'Категория товара', 'Количество продаж', 'Цена за единицу', 'Общая стоимость'])

    ob_vir = 0
    
    # Записываем данные
    for i in range(1, 100):
        random_date = generate_date()
        
        random_product = random.choice(prod)
        product_name = random_product[0]
        category = random_product[1]
        amount = random_product[2]
        price_product = random_product[3]
        
        ob_vir += amount*price_product
        
        writer.writerow([random.randint(1, 100000000), random_date, product_name, category, amount, price_product, amount*price_product])

# %%
dairy_products = int(prod[0][2]) * int(prod[0][3]) + int(prod[1][2]) * int(prod[1][3]) + int(prod[2][2]) * int(prod[2][3])
chocolate = int(prod[3][2]) * int(prod[3][3]) + int(prod[4][2]) * int(prod[4][3]) + int(prod[5][2]) * int(prod[5][3])
meet = int(prod[6][2]) * int(prod[6][3]) + int(prod[7][2]) * int(prod[7][3]) + int(prod[8][2]) * int(prod[8][3])
bread = int(prod[9][2]) * int(prod[9][3]) + int(prod[10][2]) * int(prod[10][3]) + int(prod[11][2]) * int(prod[11][3])
drinks = int(prod[12][2]) * int(prod[12][3]) + int(prod[13][2]) * int(prod[13][3]) + int(prod[14][2]) * int(prod[14][3])

milk_d = int(prod[0][2]) * int(prod[0][3])
kefir_d = int(prod[1][2]) * int(prod[1][3])
yogurt_d = int(prod[2][2]) * int(prod[2][3])
milka_c = int(prod[3][2]) * int(prod[3][3])
snickers_c = int(prod[4][2]) * int(prod[4][3])
twix_c = int(prod[5][2]) * int(prod[5][3])
pock_m = int(prod[6][2]) * int(prod[6][3])
chicken_m = int(prod[7][2]) * int(prod[7][3])
beef_c = int(prod[8][2]) * int(prod[8][3])
lavash_b = int(prod[9][2]) * int(prod[9][3])
bun_poppy_seeds_b = int(prod[10][2]) * int(prod[10][3])
meat_pie_b = int(prod[11][2]) * int(prod[12][3])
holly_spring_d = int(prod[12][2]) * int(prod[12][3])
baikal_d = int(prod[13][2]) * int(prod[13][3])
vitel_d = int(prod[14][2]) * int(prod[14][3])

# %%
with open('Shop.csv', newline='') as file:
    reader = csv.reader(file, delimiter='|')
    next(reader)
    amount_name= ""
    max_amount = 0
    cash_name = ""
    max_cash = 0
    for row in reader:
        if int(row[4]) > max_amount:
            amount_name= row[2]
            max_amount = int(row[4])
        if int(row[6]) > max_cash:
            cash_name = row[2]
            max_cash = int(row[6])

print("Общая выручка магазина: ", ob_vir, " рублей")
print("Товар, который был продан наибольшее количество раз: ", amount_name, " - ", max_amount ," штук")
print('Товар, который принёс наибольшую выручку: ', cash_name, " - ", max_cash, " рублей")
# Out:
# Общая выручка магазина:  188184997  рублей
# Товар, который был продан наибольшее количество раз:  Милка  -  1824  штук
# Товар, который принёс наибольшую выручку:  Свинина  -  13506900  рублей

# %%
x = ['Молоко', 'Кефир', 'Йогурт', 'Милка', 'Сникерс', 'Твикс', 'Свинина', 'Курица', 'Говядина', 'Лаваш', 'Булочка с маком', 'Пирожок с мясом', 'Святой источник', 'Байкал', 'Витель']
y = [milk_d, kefir_d, yogurt_d, milka_c, snickers_c, twix_c, pock_m, chicken_m, beef_c, lavash_b, bun_poppy_seeds_b, meat_pie_b, holly_spring_d, baikal_d, vitel_d]

z = ['Техника', 'Одежда', 'Обувь', 'Косметика', 'Аксессуары']
d = [dairy_products, chocolate, meet, meet, drinks]

a = ['Молоко', 'Кефир', 'Йогурт', 'Милка', 'Сникерс', 'Твикс', 'Свинина', 'Курица', 'Говядина', 'Лаваш', 'Булочка с маком', 'Пирожок с мясом', 'Святой источник', 'Байкал', 'Витель']
b = [int(prod[0][2]), int(prod[1][2]), int(prod[2][2]), int(prod[3][2]), int(prod[4][2]), int(prod[5][2]), int(prod[6][2]), int(prod[7][2]), int(prod[8][2]), int(prod[9][2]), int(prod[10][2]), int(prod[11][2]), int(prod[12][2]), int(prod[13][2]), int(prod[14][2])]

graph = input("Диаграмма по долям прибыли товаров - введите: 1.\nДиаграмма по долям прибыли категорий - введите: 2.\nДиаграмма по количеству проданных товаров - введите: 3.\nДиаграмма товаров по долям - введите: 4.\n")
if graph == "1":
    # Построение столбчатой диаграммы
    plt.bar(x, y)

    # Отображение диаграммы
    plt.show()
elif graph == "2":
    # Построение столбчатой диаграммы
    plt.bar(z, d)

    # Отображение диаграммы
    plt.show()
elif graph == "3":
    # Построение столбчатой диаграммы
    plt.bar(a, b)

    # Отображение диаграммы
    plt.show()#Доля каждого товара в общей выручке
elif graph == "4":
    labels = ['Молоко', 'Кефир', 'Йогурт', 'Милка', 'Сникерс', 'Твикс', 'Свинина', 'Курица', 'Говядина', 'Лаваш', 'Булочка с маком', 'Пирожок с мясом', 'Святой источник', 'Байкал', 'Витель']
    sizes = [(milk_d/ob_vir)*100, (kefir_d/ob_vir)*100, (yogurt_d/ob_vir)*100, (milka_c/ob_vir)*100, (snickers_c/ob_vir)*100, (twix_c/ob_vir)*100, (pock_m/ob_vir)*100, (chicken_m/ob_vir)*100, (beef_c/ob_vir)*100, (lavash_b/ob_vir)*100, (bun_poppy_seeds_b/ob_vir)*100, (meat_pie_b/ob_vir)*100, (holly_spring_d/ob_vir)*100, (baikal_d/ob_vir)*100, (vitel_d/ob_vir)*100,]  # Процентные доли каждой категории

    # Создание диаграммы
    plt.pie(sizes, labels=labels, autopct='%1.1f%%')

    # Добавление заголовка
    plt.title('Диаграмма товаров по долям')

    # Отображение диаграммы
    plt.show()
# Out:
# Диаграмма по долям прибыли товаров - введите: 1.
# Диаграмма по долям прибыли категорий - введите: 2.
# Диаграмма по количеству проданных товаров - введите: 3.
# Диаграмма товаров по долям - введите: 4.
#  4

# %%
# Сортировка по дате заказа
flaga = False
while flaga == False:
    order = input("В каком порядке вы хотите отссортировать заказы? В порядке от новых к давним - 1, от давних к новым - 2\n")
    if order == "1" or order == "2":
        flaga = True

with open('Shop.csv', 'r', newline='') as file:
    reader = csv.reader(file, delimiter='|')
    data = list(reader)  # Сохраняем данные из файла в список
    if order == "2":
        sorted_data = sorted(data[1:], key=lambda x: x[1], reverse=False)  # Сортируем данные по второму столбцу (дате) в обратном порядке
    elif order == "1":
        sorted_data = sorted(data[1:], key=lambda x: x[1], reverse=True)  # Сортируем данные по второму столбцу (дате) в обратном порядке
    for row in sorted_data:
        print(row)
# Out:
# В каком порядке вы хотите отссортировать заказы? В порядке от новых к давним - 1, от давних к новым - 2
#  1
# ['17427931', '2022-06-27', 'Лаваш', 'Хлеб', '1121', '333', '373293']
# ['51047543', '2022-06-19', 'Лаваш', 'Хлеб', '1121', '333', '373293']
# ['40889808', '2022-06-12', 'Лаваш', 'Хлеб', '1121', '333', '373293']
# ['44427785', '2022-06-08', 'Байкал', 'Напитки', '444', '2574', '1142856']
# ['1453029', '2022-06-06', 'Витель', 'Напитки', '249', '7481', '1862769']
# ['74165350', '2022-05-21', 'Сникерс', 'Шоколад', '56', '2747', '153832']
# ['17628824', '2022-05-02', 'Свинина', 'Мясо', '825', '16372', '13506900']
# ['87511104', '2022-04-21', 'Сникерс', 'Шоколад', '56', '2747', '153832']
# ['44005050', '2022-04-20', 'Молоко', 'Молочная продукция', '28', '8806', '246568']
# ['69108954', '2022-04-11', 'Булочка с маком', 'Хлеб', '781', '808', '631048']
# ['27112641', '2022-04-01', 'Святой источник', 'Напитки', '16', '4745', '75920']
# ['6084206', '2022-03-27', 'Булочка с маком', 'Хлеб', '781', '808', '631048']
# ['87383036', '2022-03-26', 'Молоко', 'Молочная продукция', '28', '8806', '246568']
# ['45481976', '2022-03-07', 'Говядина', 'Мясо', '541', '891', '482031']
# ['2505731', '2022-02-23', 'Лаваш', 'Хлеб', '1121', '333', '373293']
# ['9094332', '2022-02-09', 'Свинина', 'Мясо', '825', '16372', '13506900']
# ['89446570', '2022-02-09', 'Лаваш', 'Хлеб', '1121', '333', '373293']
# ['62297902', '2022-01-29', 'Булочка с маком', 'Хлеб', '781', '808', '631048']
# ['20941562', '2021-12-28', 'Святой источник', 'Напитки', '16', '4745', '75920']
# ['87439406', '2021-12-25', 'Пирожок с мясом', 'Хлеб', '61', '826', '50386']
# ['68829050', '2021-12-17', 'Твикс', 'Шоколад', '690', '5505', '3798450']
# ['1276845', '2021-12-16', 'Говядина', 'Мясо', '541', '891', '482031']
# ['29459215', '2021-12-07', 'Говядина', 'Мясо', '541', '891', '482031']
# ['91410185', '2021-11-29', 'Лаваш', 'Хлеб', '1121', '333', '373293']
# ['99962124', '2021-11-26', 'Твикс', 'Шоколад', '690', '5505', '3798450']
# ['69667192', '2021-11-25', 'Свинина', 'Мясо', '825', '16372', '13506900']
# ['87631072', '2021-11-21', 'Свинина', 'Мясо', '825', '16372', '13506900']
# ['59372240', '2021-11-21', 'Йогурт', 'Молочная продукция', '79', '49109', '3879611']
# ['87983450', '2021-11-16', 'Сникерс', 'Шоколад', '56', '2747', '153832']
# ['22003510', '2021-11-15', 'Свинина', 'Мясо', '825', '16372', '13506900']
# ['99085380', '2021-11-14', 'Говядина', 'Мясо', '541', '891', '482031']
# ['19668840', '2021-11-11', 'Лаваш', 'Хлеб', '1121', '333', '373293']
# ['27197118', '2021-11-09', 'Сникерс', 'Шоколад', '56', '2747', '153832']
# ['28813019', '2021-11-08', 'Кефир', 'Молочная продукция', '23', '79640', '1831720']
# ['28816210', '2021-11-08', 'Булочка с маком', 'Хлеб', '781', '808', '631048']
# ['55860185', '2021-11-04', 'Байкал', 'Напитки', '444', '2574', '1142856']
# ['11363194', '2021-10-31', 'Лаваш', 'Хлеб', '1121', '333', '373293']
# ['67590922', '2021-10-25', 'Лаваш', 'Хлеб', '1121', '333', '373293']
# ['57373767', '2021-10-15', 'Курица', 'Мясо', '59', '1344', '79296']
# ['90858488', '2021-10-07', 'Булочка с маком', 'Хлеб', '781', '808', '631048']
# ['80583912', '2021-10-02', 'Говядина', 'Мясо', '541', '891', '482031']
# ['79587878', '2021-09-15', 'Лаваш', 'Хлеб', '1121', '333', '373293']
# ['94799761', '2021-09-10', 'Свинина', 'Мясо', '825', '16372', '13506900']
# ['3058353', '2021-09-09', 'Лаваш', 'Хлеб', '1121', '333', '373293']
# ['17190321', '2021-09-09', 'Кефир', 'Молочная продукция', '23', '79640', '1831720']
# ['30480241', '2021-09-07', 'Свинина', 'Мясо', '825', '16372', '13506900']
# ['50178585', '2021-08-23', 'Говядина', 'Мясо', '541', '891', '482031']
# ['31077237', '2021-08-19', 'Сникерс', 'Шоколад', '56', '2747', '153832']
# ['56359542', '2021-08-16', 'Говядина', 'Мясо', '541', '891', '482031']
# ['46748056', '2021-08-16', 'Витель', 'Напитки', '249', '7481', '1862769']
# ['95933785', '2021-08-14', 'Лаваш', 'Хлеб', '1121', '333', '373293']
# ['39183775', '2021-08-13', 'Пирожок с мясом', 'Хлеб', '61', '826', '50386']
# ['30332364', '2021-08-13', 'Молоко', 'Молочная продукция', '28', '8806', '246568']
# ['68484224', '2021-08-07', 'Святой источник', 'Напитки', '16', '4745', '75920']
# ['87783288', '2021-07-15', 'Святой источник', 'Напитки', '16', '4745', '75920']
# ['80186955', '2021-06-29', 'Лаваш', 'Хлеб', '1121', '333', '373293']
# ['76722101', '2021-06-26', 'Пирожок с мясом', 'Хлеб', '61', '826', '50386']
# ['25391690', '2021-06-10', 'Твикс', 'Шоколад', '690', '5505', '3798450']
# ['79015776', '2021-06-10', 'Молоко', 'Молочная продукция', '28', '8806', '246568']
# ['35757302', '2021-05-23', 'Сникерс', 'Шоколад', '56', '2747', '153832']
# ['79860069', '2021-05-19', 'Лаваш', 'Хлеб', '1121', '333', '373293']
# ['15849905', '2021-05-18', 'Витель', 'Напитки', '249', '7481', '1862769']
# ['3165550', '2021-05-10', 'Святой источник', 'Напитки', '16', '4745', '75920']
# ['86607145', '2021-04-25', 'Милка', 'Шоколад', '1824', '1337', '2438688']
# ['44435689', '2021-04-22', 'Сникерс', 'Шоколад', '56', '2747', '153832']
# ['56892339', '2021-04-17', 'Булочка с маком', 'Хлеб', '781', '808', '631048']
# ['91433592', '2021-04-16', 'Милка', 'Шоколад', '1824', '1337', '2438688']
# ['57387893', '2021-04-11', 'Курица', 'Мясо', '59', '1344', '79296']
# ['96777833', '2021-04-06', 'Булочка с маком', 'Хлеб', '781', '808', '631048']
# ['4673349', '2021-03-11', 'Кефир', 'Молочная продукция', '23', '79640', '1831720']
# ['2021383', '2021-03-08', 'Святой источник', 'Напитки', '16', '4745', '75920']
# ['13657418', '2021-03-03', 'Байкал', 'Напитки', '444', '2574', '1142856']
# ['15848229', '2021-02-26', 'Сникерс', 'Шоколад', '56', '2747', '153832']
# ['61054660', '2021-02-15', 'Кефир', 'Молочная продукция', '23', '79640', '1831720']
# ['31883887', '2021-02-14', 'Милка', 'Шоколад', '1824', '1337', '2438688']
# ['46785167', '2021-02-07', 'Булочка с маком', 'Хлеб', '781', '808', '631048']
# ['15930474', '2021-02-04', 'Йогурт', 'Молочная продукция', '79', '49109', '3879611']
# ['27709935', '2021-01-26', 'Молоко', 'Молочная продукция', '28', '8806', '246568']
# ['79763412', '2021-01-22', 'Говядина', 'Мясо', '541', '891', '482031']
# ['77689539', '2021-01-13', 'Говядина', 'Мясо', '541', '891', '482031']
# ['90716820', '2021-01-09', 'Говядина', 'Мясо', '541', '891', '482031']
# ['29203447', '2021-01-09', 'Молоко', 'Молочная продукция', '28', '8806', '246568']
# ['43828031', '2021-01-05', 'Курица', 'Мясо', '59', '1344', '79296']
# ['32226291', '2020-12-31', 'Лаваш', 'Хлеб', '1121', '333', '373293']
# ['35613876', '2020-12-19', 'Байкал', 'Напитки', '444', '2574', '1142856']
# ['28540148', '2020-12-11', 'Лаваш', 'Хлеб', '1121', '333', '373293']
# ['27220994', '2020-12-09', 'Пирожок с мясом', 'Хлеб', '61', '826', '50386']
# ['31727618', '2020-12-07', 'Свинина', 'Мясо', '825', '16372', '13506900']
# ['84403574', '2020-12-07', 'Кефир', 'Молочная продукция', '23', '79640', '1831720']
# ['25530301', '2020-12-04', 'Курица', 'Мясо', '59', '1344', '79296']
# ['43094150', '2020-12-02', 'Курица', 'Мясо', '59', '1344', '79296']
# ['8246477', '2020-11-28', 'Лаваш', 'Хлеб', '1121', '333', '373293']
# ['23129724', '2020-11-17', 'Курица', 'Мясо', '59', '1344', '79296']
# ['95166490', '2020-11-04', 'Милка', 'Шоколад', '1824', '1337', '2438688']
# ['4271327', '2020-10-31', 'Лаваш', 'Хлеб', '1121', '333', '373293']
# ['80489260', '2020-10-10', 'Святой источник', 'Напитки', '16', '4745', '75920']
# ['12372528', '2020-10-03', 'Твикс', 'Шоколад', '690', '5505', '3798450']
# ['25167286', '2020-10-03', 'Твикс', 'Шоколад', '690', '5505', '3798450']
# ['3185851', '2020-09-22', 'Твикс', 'Шоколад', '690', '5505', '3798450']

# %%
# Вывод таблицы с заказами конкретного товара 
with open('Shop.csv', 'r', newline='') as file:
    reader = csv.reader(file, delimiter='|')
    rows = list(reader)  # Сохраняем строки из файла в список
    input_things = str(input("Введите название товара, продажи по которому хотелось бы увидеть продажи: \n"))
    print("\nЗаказы - ", input_things)
    for rew in rows:  # Используем сохраненный список строк
        if input_things == rew[2]:
            print(rew)
    print("\n")
# Out:
# Введите название товара, продажи по которому хотелось бы увидеть продажи:
#  Твикс
# Заказы -  Твикс
# ['12372528', '2020-10-03', 'Твикс', 'Шоколад', '690', '5505', '3798450']
# ['99962124', '2021-11-26', 'Твикс', 'Шоколад', '690', '5505', '3798450']
# ['3185851', '2020-09-22', 'Твикс', 'Шоколад', '690', '5505', '3798450']
# ['68829050', '2021-12-17', 'Твикс', 'Шоколад', '690', '5505', '3798450']
# ['25391690', '2021-06-10', 'Твикс', 'Шоколад', '690', '5505', '3798450']
# ['25167286', '2020-10-03', 'Твикс', 'Шоколад', '690', '5505', '3798450']

# %%
#Документация tkinter
#'https://docs.python.org/3/library/tkinter.html'
#'https://metanit.com/python/tkinter/'

information = Tk()
information.title('Курсовая работа')
information.geometry("300x150+500+500")
information.config(bg = 'green')
information.resizable(False, False)

# Информация
def infoButtonClick():
    informationWindow = Toplevel(information)
    informationWindow.title('Информация')
    informationWindow.geometry("270x170+515+500")
    informationWindow.config(bg = 'green')
    label1 = ttk.Label(informationWindow, text="Курсовая работа")
    label2 = ttk.Label(informationWindow, text="Выполнил:\nПетрушин Евгений Игоревич\nГруппа: БФИ2204\n\n\nTelegram:\n@Insafoo")
    label1.pack()
    label2.pack()

info_button = ttk.Button(text="Информация", width = 40, command=infoButtonClick)
info_button.grid(row=30, column=3, padx=25, pady=50)
information.mainloop()
